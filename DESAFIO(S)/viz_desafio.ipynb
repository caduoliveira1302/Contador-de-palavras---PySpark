# %%
import pandas as pd

# %%
df_neg_reddit = pd.read_csv('C:/Users/cedua/CDIA - PUCSP/PROJETO PySpark - SAVINO/Contador-de-palavras---PySpark/DESAFIO(S)/Contagem_NEGReddit.csv')
df_neg_reddit = df_neg_reddit.drop(['Unnamed: 0'], axis=1)
df_neg_reddit = df_neg_reddit.sort_values('Frequência', ascending=False)
df_neg_reddit.head(20)
# Out:
#       Palavra  Frequência
# 5     protein          68
# 24     powder          19
# 4        whey          11
# 46        bad          11
# 55    chicken           7
# 59      taste           6
# 61       sick           6
# 179     weird           6
# 20     shakes           6
# 17         'm           5
# 1      anyone           5
# 31   creatine           5
# 156      bars           5
# 40     muscle           4
# 47      tried           4
# 144        im           4
# 72     intake           4
# 0         n't           4
# 69       days           4
# 2        make           4
