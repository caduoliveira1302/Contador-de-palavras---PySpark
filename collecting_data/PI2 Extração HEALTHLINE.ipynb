# %%
from newspaper import Article
import pandas as pd
import warnings
from time import sleep

# %%
def get_link(url):
    article = Article(url)
    article.download()
    article.parse()
    article.nlp()

    text = article.text.lower()
    
    # Obter os artigos
    text = article.text
    
    return text

# %%
urls = [
    "https://www.healthline.com/health/best-protein-powder",
    "https://www.healthline.com/nutrition/best-pre-workout-for-women",
    "https://www.healthline.com/nutrition/best-tasting-protein-powder",
    "https://www.ninjasuplementos.com.br/pagina/blog-tudo-sobre-o-whey-protein.html"
]


df = pd.DataFrame(columns=['Artigo'])

for url in urls:
    text = get_link(url)
    df.loc[len(df)] = [text]

display(df)
# Out:
#                                               Artigo
# 0  We include products we think are useful for ou...
# 1  Here are the 10 best pre-workout supplements f...
# 2  We do the research so you can find trusted pro...
# 3  Nova Postagem\n\n\n\nWhey protein, suas difere...

# %%
#with open('healthline.txt', 'w', encoding='utf-8') as file:
    #file.write(df.to_string(index=False))

# %%
with open('healthline.txt', 'r', encoding='utf-8') as file:
    artigo = file.read()

print(artigo)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...
