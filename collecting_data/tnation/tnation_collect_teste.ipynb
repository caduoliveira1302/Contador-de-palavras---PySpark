# %%
import pandas as pd

# %%
df = pd.read_csv('tnation_data.csv')
df
# Out:
#     Unnamed: 0                                      articles_text
# 0            0  CASEIN PROTEIN BEATS WHEY, BUT WHICH CASEIN?\n...
# 1            1  THE "BEST" PROTEIN POWDER? NOT SO FAST!\nWhat'...
# 2            2  The subject of collagen supplementation create...
# 3            3  NUTRITIONAL EVOLUTION\nPeople who want to buil...
# 4            4  Let me throw this hypothetical at you: How wou...
# 5            5  Protein is always a hot topic in weight liftin...
# 6            6  Every so often a recipe comes along that becom...
# 7            7  A segment of the population seems to be intere...
# 8            8  Back in 1999, I got an email from someone who ...
# 9            9  To paraphrase Tom Jefferson, all protein powde...
# 10          10  At first glance, protein powder from grass-fed...
# 11          11  "TOO MUCH PROTEIN IS BAD FOR YOUR BONES!"\nHea...
# 12          12  STIMULATE MUSCLE PROTEIN SYNTHESIS\nEvery bro ...
# ...

# %%
for column in df['articles_text']:
    aa = "whey" in column
    print(aa)
# Out:
# True
# False
# False
# True
# False
# False
# True
# True
# False
# True
# False
# False
# True
# True
# False
# True
# True
# False
# True
# True
