# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/cedua/CDIA - PUCSP/PROJETO PySpark - SAVINO/Contador-de-palavras---PySpark/data/final_data_sites/final_df_gsup.csv")
df
# Out:
#           words10  count
# 0            whey    229
# 1         protein    133
# 2       proteínas     72
# 3        muscular     58
# 4           leite     55
# 5          treino     53
# 6      suplemento     51
# 7           massa     51
# 8           tomar     49
# 9        proteína     49
# 10        lactose     46
# 11          tipos     44
# 12         acesso     41
# 13       nutrição     39
# 14         melhor     38
# 15          forma     37
# 16          fazer     36
# 17        artigos     34
# 18        consumo     34
# 19     benefícios     34
# 20        isolado     33
# 21    aminoácidos     31
# 22           peso     30
# 23          antes     30
# 24              –     30
# 25    concentrado     29
# 26     atividades     29
# 27           pois     29
# 28      emagrecer     29
# 29   concentração     28
# 30         growth     27
# 31           soro     27
# 32     exercícios     27
# 33         possui     27
# 34     disponível     26
# 35          corpo     26
# ...
